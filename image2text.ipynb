# %%
import warnings,logging
warnings.simplefilter('ignore')
logging.disable(logging.WARNING)

# %%
! pip install transformers -q

# %%
from transformers import pipeline

# %%
caption = pipeline('image-to-text')
# Out:
# config.json:   0%|          | 0.00/4.34k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/236 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/211 [00:00<?, ?B/s]

# %%
# !wget -O img2text.jpg 'https://cdn.pixabay.com/photo/2022/08/17/15/13/street-7392734_960_720.jpg'

from IPython.display import Image
Image(filename='img2text.jpg')
# Out:
# --2024-10-13 09:53:16--  https://cdn.pixabay.com/photo/2022/08/17/15/13/street-7392734_960_720.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.40.96, 172.64.147.160, 2606:4700:4400::6812:2860, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.40.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 158280 (155K) [binary/octet-stream]
# Saving to: ‘img2text.jpg’
#
# img2text.jpg        100%[===================>] 154.57K  --.-KB/s    in 0.03s
#
# 2024-10-13 09:53:16 (4.70 MB/s) - ‘img2text.jpg’ saved [158280/158280]

# %%
caption('img2text.jpg')
# Out:
# [{'generated_text': 'a woman riding a motorcycle down a street '}]
